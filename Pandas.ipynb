# %% [markdown]
# <a href="https://colab.research.google.com/github/mustafakaranja/Pandas-Tutorial-in-Machine-Learning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# pandas Library
#
# useful for data processing and analysis
#
# pandas data frame:
# pandas data frame is two dimentional tabular data structure with labels axes (rows and columns)

# %% [markdown]
# Pandas is mainly use in the data processing and analysis.

# %%
# importing the pandas in the code
import pandas as pd
import numpy as np

# %%
|# creating a pandas data frame

# %%
#importing the boston house price data
from sklearn.datasets import load_boston

# %%
boston_dataset = load_boston()
print(boston_dataset)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
# panda data frame

boston_df = pd.DataFrame(boston_dataset.data, columns = boston_dataset.feature_names)

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
boston_df.shape
# Out:
# (506, 13)

# %% [markdown]
# Importing the data in the csv file in the pandas

# %%
# csv file to pandas df
diabetes_df = pd.read_csv('/content/diabetes.csv')

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# load the data from a excel file to a pandas data frame
# pd.read_excel('file path')
#
# export a dataframe to a csv file.

# %%
boston_df.to_csv("boston.csv")

# %% [markdown]
# Exportinf the pandas dataframe to an excel file.
# df.to_excel("filename")

# %%
# creating the data set in the random value

random_df = pd.DataFrame(np.random.rand(200,10))
random_df.head()
random_df.shape
# Out:
# (200, 10)

# %% [markdown]
# Inspecting the data Frame

# %% [markdown]
# Finding the number of rows and column in the data set
#
# data.shape

# %%
# finding the number of rows and columns

boston_df.shape
# Out:
# (506, 13)

# %%
#first 5 rows in a data frame

boston_df.tail(
    
)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88

# %%
# information about the data base||
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %%
funding_data = pd.read_csv("/content/Funding insight input.csv")

# %%
funding_data.shape
# Out:
# (116, 10)

# %%
funding_data.head()
# Out:
#   Announcement Date            Company Funding Type Fund Raise  \
# 0        11/12/2021            Workato     Series E     200.0M
# 1        11/11/2021         GoTo Group  IPO Funding       1.3B
# 2        11/10/2021   Cerebras Systems     Series F     250.0M
# 3        11/11/2021  Applied Intuition     Series D     175.0M
# 4         11/9/2021  Contrast Security     Series E     150.0M
#
#   Company Valuation                                     Capitalist  \
# 0              5.7B                               Battery ventures
# 1             22.0B                                           ADIA
# 2              4.0B  Abu Dhabi Growth Fund and Falcon Edge Capital
# 3              3.6B                  Elad Gil, Addition and Coatue
# 4               NaN                      Liberty Strategic Capital
#
#                                   Industry       State        Country  \
# 0            Information and communication  California  United States
# ...

# %%
funding_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Announcement Date  114 non-null    object
#  1   Company            116 non-null    object
#  2   Funding Type       116 non-null    object
#  3   Fund Raise         116 non-null    object
#  4   Company Valuation  12 non-null     object
#  5   Capitalist         116 non-null    object
#  6   Industry           116 non-null    object
#  7   State              116 non-null    object
#  8   Country            116 non-null    object
#  9   Type of Company    116 non-null    object
# dtypes: object(10)
# memory usage: 9.2+ KB

# %%
funding_data.isnull().sum()
# Out:
# Announcement Date      2
# Company                0
# Funding Type           0
# Fund Raise             0
# Company Valuation    104
# Capitalist             0
# Industry               0
# State                  0
# Country                0
# Type of Company        0
# dtype: int64

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# counting the values based on the labels

diabetes_df.value_counts("Outcome")
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
funding_data.value_counts("Industry")
# Out:
# Industry
# Information and communication                58
# Human health and social work activities      21
# Financial and insurance activities            8
# Food, Agriculture, forestry and fishing       5
# Automotive                                    4
# Transportation and storage                    3
# Education                                     3
# Real estate activities                        3
# Gaming                                        2
# Wholesale and retail trade                    2
# Mining and quarrying                          1
#  Multimedia and Web Technology Industry.      1
# Legal                                         1
# Accommodation and food service activities     1
# Consumer Services                             1
# Consulting & Professional Services            1
#  Multimedia and Web Technology Industry.      1
# dtype: int64

# %%
diabetes_df.groupby("Outcome").mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
# count or number of values in the data set
funding_data.count()
# Out:
# Announcement Date    114
# Company              116
# Funding Type         116
# Fund Raise           116
# Company Valuation     12
# Capitalist           116
# Industry             116
# State                116
# Country              116
# Type of Company      116
# dtype: int64

# %%
# Standard Deviation column wise

funding_data.std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Series([], dtype: float64)

# %%
boston_df.min
boston_df.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# ...

# %%
boston_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# Menupliating the dataframe

# %%
# adding the coolumn to data frame
boston_df['price'] = boston_dataset.target

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
# removing the a row and column

boston_df.drop(index=0, axis=0)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 1    0.02731  0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729  0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237  0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905  0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# 5    0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622  3.0  222.0
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  price
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# ...

# %%
boston_df.drop(columns = "ZN", axis = 1)
# Out:
#         CRIM  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0    0.00632   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0     15.3
# 1    0.02731   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0     17.8
# 2    0.02729   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0     17.8
# 3    0.03237   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0     18.7
# 4    0.06905   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0     18.7
# ..       ...    ...   ...    ...    ...   ...     ...  ...    ...      ...
# 501  0.06263  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0     21.0
# 502  0.04527  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0     21.0
# 503  0.06076  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0     21.0
# 504  0.10959  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0     21.0
# 505  0.04741  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0     21.0
#
#           B  LSTAT  price
# 0    396.90   4.98   24.0
# ...

# %%
boston_df.iloc[2]
# Out:
# CRIM         0.02729
# ZN           0.00000
# INDUS        7.07000
# CHAS         0.00000
# NOX          0.46900
# RM           7.18500
# AGE         61.10000
# DIS          4.96710
# RAD          2.00000
# TAX        242.00000
# PTRATIO     17.80000
# B          392.83000
# LSTAT        4.03000
# price       34.70000
# Name: 2, dtype: float64

# %%
boston_df.iloc[:,0]  # print the First column of data frame
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64
